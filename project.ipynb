# %%
import pandas as pd

df = pd.read_csv("train.csv")

df.head()
# Out:
#              Question                                            Options  \
# 0  下列各项，最符合“主诉”书写要求的是  A 患高血压病3年\nB 心绞痛反复发作3年\nC 3年前开始多饮，多食，多尿\nD 吞咽困...
# 1      下列除哪项外均符合问诊的要求  A 态度和蔼，言语亲切\nB 要将患者陈述的内容去粗取精，去伪存真\nC 交谈时避免使用特定...
# 2     我国高血压病最常见的死亡原因是         A 高血压危象\nB 急性脑血管病\nC 尿毒症\nD 心力衰竭\nE 缺血性心脏病
# 3       属循环系统疾病问诊内容的是                   A 呼吸困难\nB 呕吐\nC 腰痛\nD 肌肉震颤\nE 腹泻
# 4       属呼吸系统疾病问诊内容的是                   A 呼吸困难\nB 呕吐\nC 腰痛\nD 肌肉震颤\nE 腹泻
#
#   Answer                                        Explanation
# 0      D  主诉一般包括就诊主要症状（或体征）及持续时间，要简明精炼，一般在1～2句，20字左右。患高血...
# 1      D  在问诊过程中，医生应避免诱导性提问，即避免在措辞上已暗示了期望的答案，使患者易于默认或符合医...
# 2      B  在我国高血压病最常见的死亡原因为急性脑血管病（B对），高血压危象（A错）、尿毒症（C错）、心...
# 3      A  循环系统疾病主要症状为：呼吸困难（A对）、心悸、咳嗽、咯血、水肿及心前区疼痛等。呼吸困难、咳...
# 4      A  呼吸系统疾病的主要症状为：呼吸困难（A对）、咳嗽、咳痰、咯血、胸痛。循呼吸困难、心悸、咳嗽、...

# %%
print(len(df))
# Out:
# 54497

# %%
# df_shuffled = df.sample(frac=1, random_state=42)
df_shuffled = df


df_sampled = df_shuffled.head(200)



df_sampled
# Out:
#                Question                                            Options  \
# 0    下列各项，最符合“主诉”书写要求的是  A 患高血压病3年\nB 心绞痛反复发作3年\nC 3年前开始多饮，多食，多尿\nD 吞咽困...
# 1        下列除哪项外均符合问诊的要求  A 态度和蔼，言语亲切\nB 要将患者陈述的内容去粗取精，去伪存真\nC 交谈时避免使用特定...
# 2       我国高血压病最常见的死亡原因是         A 高血压危象\nB 急性脑血管病\nC 尿毒症\nD 心力衰竭\nE 缺血性心脏病
# 3         属循环系统疾病问诊内容的是                   A 呼吸困难\nB 呕吐\nC 腰痛\nD 肌肉震颤\nE 腹泻
# 4         属呼吸系统疾病问诊内容的是                   A 呼吸困难\nB 呕吐\nC 腰痛\nD 肌肉震颤\nE 腹泻
# ..                  ...                                                ...
# 195          病理性蛋白尿，可见于          A 剧烈活动后\nB 严重受寒\nC 直立性蛋白尿\nD 妊娠中毒\nE 以上均非
# 196        血白细胞总数增多，可见于   A 伤寒杆菌感染\nB 再生障碍性贫血\nC 急性失血\nD 使用氯霉素的影响\nE 脾功能亢进
# 197     下列情况，不出现尿酮体阳性的是        A 饥饿状态\nB 暴饮暴食\nC 妊娠剧烈呕吐\nD 糖尿病酮症酸中毒\nE 厌食症
# 198    骨髓细胞内出现Auer小体常见于  A 急性淋巴细胞白血病\nB 急性粒细胞白血病\nC 慢性粒细胞白血病\nD 溶血性贫血\n...
# 199       对诊断心肌梗死最有意义的是     A 淀粉酶\nB 血清转氨酶\nC 谷氨酰基转肽酶\nD 血清碱性磷酸酶\nE 肌酸磷酸激酶
#
#     Answer                                        Explanation
# ...

# %%
question_info = df_sampled.drop(columns=["Answer","Explanation"])
answer_list = df_sampled["Answer"]

output_path = "question.csv"
question_info.to_csv(output_path, index=False)
answer_list.to_csv("answer.csv",index=False)

# 显示前3个示例
question_info[:3]
# Out:
#              Question                                            Options
# 0  下列各项，最符合“主诉”书写要求的是  A 患高血压病3年\nB 心绞痛反复发作3年\nC 3年前开始多饮，多食，多尿\nD 吞咽困...
# 1      下列除哪项外均符合问诊的要求  A 态度和蔼，言语亲切\nB 要将患者陈述的内容去粗取精，去伪存真\nC 交谈时避免使用特定...
# 2     我国高血压病最常见的死亡原因是         A 高血压危象\nB 急性脑血管病\nC 尿毒症\nD 心力衰竭\nE 缺血性心脏病

# %%
answer_list[:3]
# type(answer_list)
# Out:
# 0    D
# 1    D
# 2    B
# Name: Answer, dtype: object

# %%
chunk_size = 20
chunks = [question_info.iloc[i:i + chunk_size] for i in range(0, len(df_sampled), chunk_size)]

output_paths = []
for i, chunk in enumerate(chunks):
    path = f"question_batch_{i+1}.csv"
    chunk.to_csv(path, index=False)
    output_paths.append(path)

output_paths
# Out:
# ['question_batch_1.csv',
#  'question_batch_2.csv',
#  'question_batch_3.csv',
#  'question_batch_4.csv',
#  'question_batch_5.csv',
#  'question_batch_6.csv',
#  'question_batch_7.csv',
#  'question_batch_8.csv',
#  'question_batch_9.csv',
#  'question_batch_10.csv']

# %%
ans=[]
ans.append([['D', 'D', 'B', 'A', 'A', 'D', 'E', 'E', 'A', 'A', 'C', 'C', 'C', 'A', 'C', 'D', 'C', 'C', 'C', 'B'],
['D', 'A', 'E', 'B', 'D', 'E', 'B', 'A', 'B', 'A', 
 'C', 'B', 'C', 'D', 'E', 'D', 'D', 'A', 'B', 'A'],
 ['B', 'A', 'A', 'A', 'D', 'B', 'A', 'A', 'C', 'B',
 'A', 'E', 'B', 'A', 'E', 'D', 'A', 'E', 'B', 'B']
,['A', 'E', 'E', 'B', 'C', 'B', 'B', 'B', 'D', 'A',
 'D', 'D', 'D', 'B', 'C', 'D', 'C', 'D', 'E', 'C']
 ,['E', 'B', 'D', 'E', 'C', 'A', 'E', 'B', 'C', 'C',
 'B', 'D', 'B', 'A', 'B', 'E', 'B', 'C', 'A', 'A']
,['E', 'B', 'D', 'E', 'C', 'A', 'E', 'B', 'C', 'C',
 'B', 'D', 'B', 'A', 'B', 'E', 'B', 'C', 'A', 'A']
,['E', 'C', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C',
 'A', 'D', 'B', 'D', 'E', 'C', 'B', 'D', 'D', 'C']
,['E', 'E', 'D', 'A', 'A', 'C', 'C', 'A', 'B', 'E',
 'B', 'E', 'D', 'D', 'A', 'D', 'D', 'B', 'D', 'B']
,['A', 'E', 'E', 'D', 'A', 'E', 'C', 'E', 'A', 'E',
 'B', 'E', 'C', 'C', 'C', 'D', 'B', 'D', 'B', 'D']
,['D', 'C', 'E', 'C', 'C', 'D', 'C', 'D', 'B', 'A',
 'C', 'D', 'D', 'E', 'E', 'D', 'C', 'B', 'B', 'E']]
)
gpt = []
for group in ans:
    for sublist in group:
        gpt.extend(sublist) 
print(gpt)
# Out:
# ['D', 'D', 'B', 'A', 'A', 'D', 'E', 'E', 'A', 'A', 'C', 'C', 'C', 'A', 'C', 'D', 'C', 'C', 'C', 'B', 'D', 'A', 'E', 'B', 'D', 'E', 'B', 'A', 'B', 'A', 'C', 'B', 'C', 'D', 'E', 'D', 'D', 'A', 'B', 'A', 'B', 'A', 'A', 'A', 'D', 'B', 'A', 'A', 'C', 'B', 'A', 'E', 'B', 'A', 'E', 'D', 'A', 'E', 'B', 'B', 'A', 'E', 'E', 'B', 'C', 'B', 'B', 'B', 'D', 'A', 'D', 'D', 'D', 'B', 'C', 'D', 'C', 'D', 'E', 'C', 'E', 'B', 'D', 'E', 'C', 'A', 'E', 'B', 'C', 'C', 'B', 'D', 'B', 'A', 'B', 'E', 'B', 'C', 'A', 'A', 'E', 'B', 'D', 'E', 'C', 'A', 'E', 'B', 'C', 'C', 'B', 'D', 'B', 'A', 'B', 'E', 'B', 'C', 'A', 'A', 'E', 'C', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C', 'A', 'D', 'B', 'D', 'E', 'C', 'B', 'D', 'D', 'C', 'E', 'E', 'D', 'A', 'A', 'C', 'C', 'A', 'B', 'E', 'B', 'E', 'D', 'D', 'A', 'D', 'D', 'B', 'D', 'B', 'A', 'E', 'E', 'D', 'A', 'E', 'C', 'E', 'A', 'E', 'B', 'E', 'C', 'C', 'C', 'D', 'B', 'D', 'B', 'D', 'D', 'C', 'E', 'C', 'C', 'D', 'C', 'D', 'B', 'A', 'C', 'D', 'D', 'E', 'E', 'D', 'C', 'B', 'B', 'E
# ...

# %%
df = pd.read_csv("answer.csv")
true_answers = df['Answer'].tolist()
print(f"GPTsum: {len(gpt)}")
print(f"truthSum: {len(true_answers)}")
# Out:
# GPTsum: 200
# truthSum: 200

# %%
correct = sum([g == t for g, t in zip(gpt, true_answers)])

wrong_indices = [i for i, (g, t) in enumerate(zip(gpt, true_answers)) if g != t]

print(f"ALLnum: {len(true_answers)}")
print(f"Correct: {correct}")
print(f"Accuracy: {correct / len(true_answers) * 100:.2f}%")
print(f"Wrong indices: {wrong_indices}")
# Out:
# ALLnum: 200
# Correct: 169
# Accuracy: 84.50%
# Wrong indices: [12, 20, 39, 44, 51, 54, 58, 64, 66, 74, 77, 92, 93, 104, 105, 106, 108, 114, 115, 116, 117, 118, 119, 120, 121, 136, 156, 161, 173, 189, 190]

# %%
# Original Chinese questions and options
batch1 = [
    ("Which of the following best conforms to the standard for writing a chief complaint?",
     "A Hypertension for 3 years\nB Recurrent angina for 3 years\nC Polyuria, polydipsia, and polyphagia for 3 years\nD Progressive dysphagia for more than one month\nE Diagnosed with lung cancer at another hospital, referred for consultation"),
    
    ("All of the following meet the requirements of history taking, EXCEPT:",
     "A Kind attitude and gentle speech\nB Filtering and refining patient statements\nC Avoiding technical medical terminology in conversation\nD Physicians should ask more suggestive questions\nE For critical patients, collect essential info first, supplement later"),
    
    ("The most common cause of death due to hypertension in China is:",
     "A Hypertensive crisis\nB Acute cerebrovascular accident\nC Uremia\nD Heart failure\nE Ischemic heart disease"),
    
    ("Which of the following symptoms is related to the circulatory system?",
     "A Dyspnea\nB Vomiting\nC Low back pain\nD Muscle tremors\nE Diarrhea"),
    
    ("Which of the following symptoms is related to the respiratory system?",
     "A Dyspnea\nB Vomiting\nC Low back pain\nD Muscle tremors\nE Diarrhea"),
    
    ("All of the following are components required for chief complaint documentation, EXCEPT:",
     "A It refers to the primary symptom leading the patient to seek care\nB Usually no more than 20 characters\nC A precise complaint can help guide diagnosis\nD Use diagnostic terminology when documenting\nE If no prominent symptom, use purpose of visit as complaint"),
    
    ("Which of the following describes chest pain from esophageal disease?",
     "A Triggered by stress\nB Relieved by sublingual nitroglycerin\nC Worse with breathing, relieved by breath holding\nD Aggravated by pressure\nE Worsened by eating"),
    
    ("All of the following can cause chest pain, EXCEPT:",
     "A Herpes zoster\nB Lung cancer\nC Pneumothorax\nD Pericarditis\nE Asthma"),
    
    ("All of the following are acute abdomen conditions, EXCEPT:",
     "A Peptic ulcer disease\nB Acute pancreatitis with jaundice\nC Gastrointestinal perforation\nD Intestinal obstruction\nE Solid organ rupture"),
    
    ("Which disease may present with fever and dry cough?",
     "A Pleurisy\nB Pneumococcal pneumonia\nC Cavitary pulmonary tuberculosis\nD Bronchiectasis\nE Laryngeal edema"),
    
    ("Chronic cough, purulent sputum, and recurrent hemoptysis are most common in:",
     "A Chronic bronchitis\nB Bronchogenic carcinoma\nC Bronchiectasis\nD Pulmonary tuberculosis\nE Pneumonia"),
    
    ("Common symptom of biliary tract stones is:",
     "A Chronic regular epigastric pain\nB Irregular epigastric pain\nC Right upper quadrant colic\nD Severe left upper abdominal pain\nE Diffuse severe abdominal pain"),
    
    ("A body temperature >39°C with daily fluctuation >2°C is often seen in:",
     "A Rheumatic fever\nB Typhoid fever\nC Malaria\nD Lobar pneumonia\nE Heat stroke"),
    
    ("Peptic ulcer usually presents as:",
     "A Chronic regular epigastric pain\nB Irregular epigastric pain\nC Right upper quadrant colic\nD Severe left upper abdominal pain\nE Diffuse severe abdominal pain"),
    
    ("Chest pain of dry pleurisy is characterized by:",
     "A Triggered by stress\nB Relieved by sublingual nitroglycerin\nC Worse with breathing, relieved by breath holding\nD Aggravated by pressure\nE Worsened by eating"),
    
    ("Hematuria with severe abdominal pain is most commonly caused by:",
     "A Nephritis\nB Bladder tuberculosis\nC Renal tumor\nD Urinary tract stones\nE Henoch–Schönlein purpura"),
    
    ("Fixed splitting of the second heart sound is most commonly seen in:",
     "A Patent ductus arteriosus\nB Ventricular septal defect\nC Atrial septal defect\nD Right bundle branch block\nE Left bundle branch block"),
    
    ("Male, 45 years old, recently noticed black stools and irregular upper abdominal pain. On exam, a 1×1.2 cm hard lymph node was palpated in the left supraclavicular fossa. Fecal occult blood test (+++). What should be considered first?",
     "A Peptic ulcer disease\nB Biliary tract infection with bleeding\nC Gastric cancer\nD Thrombocytopenic purpura\nE Liver cirrhosis"),
    
    ("Which of the following is a respiratory pattern seen in metabolic acidosis?",
     "A Cheyne-Stokes respiration\nB Sighing respiration\nC Kussmaul respiration\nD Biot’s respiration\nE Sob-like respiration"),
    
    ("Which condition is most associated with vomiting triggered by head position changes?",
     "A Encephalitis\nB Otogenic vertigo\nC Pregnancy-related vomiting\nD Uremia\nE Diabetic ketoacidosis")
]
# New batch of translated questions and options
batch2 = [
    ("A 20-year-old female suddenly developed upper abdominal pain that was relieved by pressure. What is the most likely diagnosis?",
     "A Gastric ulcer\nB Gastric spasm\nC Gastritis\nD Acute gastric dilatation\nE Gastric perforation"),
    
    ("Which of the following describes the type of dyspnea seen in bronchial asthma?",
     "A Expiratory\nB Inspiratory\nC Mixed\nD Paroxysmal\nE Absent abdominal breathing"),
    
    ("Paroxysmal expiratory dyspnea is most commonly seen in:",
     "A Pneumothorax\nB Tracheal foreign body\nC Acute bronchitis\nD Acute myocardial infarction\nE Chronic obstructive pulmonary disease"),
    
    ("Chest X-ray shows a dense shadow in the right lower lung with a round cavity containing a fluid level and thick, smooth walls. What is the most likely diagnosis?",
     "A Pulmonary bulla\nB Lung abscess\nC Cavitary infiltrative pulmonary tuberculosis\nD Chronic fibrocavitary tuberculosis\nE Cavitary peripheral lung cancer"),
    
    ("Which of the following is a typical symptom of hepatic encephalopathy?",
     "A Resting tremor\nB Action tremor\nC Senile tremor\nD Asterixis (flapping tremor)\nE Carpopedal spasm"),
    
    ("Which of the following is a non-infectious cause of fever?",
     "A Tuberculosis\nB Pneumonia\nC Acute pyelonephritis\nD Typhoid fever\nE Serum sickness"),
    
    ("Which of the following is NOT considered a disorder of consciousness?",
     "A Somnolence\nB Convulsions\nC Confusion\nD Delirium\nE Coma"),
    
    ("All of the following may cause hepatocellular jaundice, EXCEPT:",
     "A Malaria\nB Acute hepatitis A\nC Toxic hepatitis\nD Leptospirosis\nE Hepatocellular carcinoma"),
    
    ("All of the following diseases may present with dry cough, EXCEPT:",
     "A Acute pharyngitis\nB Chronic bronchitis\nC Pleurisy\nD Mild pulmonary tuberculosis\nE Early acute bronchitis"),
    
    ("What is the typical fever pattern in pneumococcal pneumonia?",
     "A Sustained fever\nB Remittent fever\nC Intermittent fever\nD Relapsing fever\nE Irregular fever"),
    
    ("Which of the following is a clinical manifestation of acute gastritis?",
     "A Vomitus contains undigested food with foul odor\nB Vomitus is yellow-green and fecal-smelling\nC Vomitus contains mucus and food\nD Vomitus contains blood\nE Persistent retching after vomiting stomach contents"),
    
    ("Acute left heart failure is most commonly accompanied by:",
     "A Rusty sputum\nB Pink frothy sputum\nC Profuse fresh blood in sputum\nD Purulent sputum\nE Dry cough"),
    
    ("Convulsions with hypertension and limb paralysis are commonly seen in:",
     "A Hysteria\nB Tetanus\nC Cerebrovascular disease\nD Toxic dysentery\nE Myofascitis"),
    
    ("Consciousness mostly lost, but pharyngeal and corneal reflexes still present under strong stimulation. What is this state?",
     "A Delirium\nB Somnolence\nC Stupor\nD Light coma\nE Deep coma"),
    
    ("Projectile vomiting is most commonly seen in:",
     "A Otogenic vertigo\nB Gastritis\nC Intestinal obstruction\nD Uremia\nE Encephalitis"),
    
    ("Which of the following is NOT a cause of inspiratory dyspnea?",
     "A Laryngeal edema\nB Tracheal compression\nC Tracheal foreign body\nD Bronchial asthma\nE Laryngeal cancer"),
    
    ("All of the following may cause central vomiting, EXCEPT:",
     "A Hypertensive encephalopathy\nB Digitalis intoxication\nC Uremia\nD Cholecystitis\nE Pregnancy-related vomiting"),
    
    ("Which of the following conditions is associated with altered consciousness and hallucinations?",
     "A Delirium\nB Somnolence\nC Stupor\nD Light coma\nE Deep coma"),
    
    ("Convulsions accompanied by risus sardonicus (sardonic grin) are seen in:",
     "A Hysteria\nB Tetanus\nC Cerebrovascular disease\nD Toxic dysentery\nE Myofascitis"),
    
    ("What is the mechanism behind nocturnal paroxysmal dyspnea in left heart failure?",
     "A Ventilation impairment\nB Gas exchange impairment\nC Suppressed respiratory center\nD Altered peripheral chemoreceptor response\nE Acidosis")
]

# New batch of questions for translation
batch3 = [
    ("What is a clinical manifestation of acute cholecystitis?",
     "A Vomitus contains undigested food with foul odor\nB Vomitus is yellow-green and fecal-smelling\nC Vomitus contains large amounts of mucus and food\nD Vomitus contains blood\nE Persistent retching after vomiting stomach contents"),
    
    ("A barking cough is commonly seen in:",
     "A Acute laryngitis\nB Acute bronchitis\nC Bronchial asthma\nD Pulmonary tuberculosis\nE Lung cancer"),
    
    ("Which of the following is NOT a manifestation of delirium?",
     "A Significant loss of consciousness\nB Delirious speech\nC Restlessness\nD Confusion\nE Hallucinations"),
    
    ("Among the following pulmonary diseases, which most commonly causes hemoptysis?",
     "A Pulmonary tuberculosis\nB Pulmonary congestion\nC Pulmonary embolism\nD Paragonimiasis\nE Pulmonary mycosis"),
    
    ("Anuria is defined as urine output less than how much in 24 hours in adults?",
     "A 150ml\nB 100ml\nC 80ml\nD 50ml\nE 10ml"),
    
    ("Remittent fever is commonly seen in:",
     "A Typhoid fever\nB Septicemia\nC Pneumonia\nD Bronchitis\nE Brucellosis"),
    
    ("All of the following can cause peripheral vomiting, EXCEPT:",
     "A Digitalis intoxication\nB Acute gastritis\nC Gastric perforation\nD Cholecystitis\nE Pharyngeal stimulation"),
    
    ("Which disease can cause inspiratory dyspnea?",
     "A Tracheal tumor\nB Chronic obstructive pulmonary emphysema\nC Bronchial asthma\nD Pneumothorax\nE Massive pulmonary atelectasis"),
    
    ("Consciousness disorder with constricted pupils is commonly seen in:",
     "A Atropine poisoning\nB Alcohol intoxication\nC Organophosphate poisoning\nD Epilepsy\nE Hepatic coma"),
    
    ("Which of the following statements about hemolytic jaundice is correct?",
     "A Direct bilirubin test strongly positive\nB Conjugated bilirubin negative in urine\nC Unconjugated bilirubin not elevated in blood\nD Urobilinogen negative in urine\nE Stools are clay-colored"),
    
    ("Pneumococcal pneumonia is commonly accompanied by:",
     "A Rust-colored sputum\nB Pink frothy sputum\nC Massive hemoptysis\nD Purulent sputum\nE Dry cough"),
    
    ("Which of the following may present with intermittent fever?",
     "A Acute pyelonephritis\nB Pneumonia\nC Rheumatic fever\nD Exudative pleuritis\nE Hodgkin’s disease"),
    
    ("Abdominal pain from biliary disease often radiates to:",
     "A Left shoulder\nB Right shoulder\nC Back\nD Left lower back\nE Inner side of right thigh"),
    
    ("A positive fecal occult blood test indicates an upper GI bleeding volume of at least:",
     "A 5–10ml\nB 10ml\nC 20ml\nD 50ml\nE 60ml"),
    
    ("What is the common fever pattern in septicemia?",
     "A Sustained fever\nB Remittent fever\nC Intermittent fever\nD Relapsing fever\nE Irregular fever"),
    
    ("What is the typical sputum characteristic of pneumococcal pneumonia?",
     "A Pink frothy sputum\nB Bright red sputum\nC Brownish sputum\nD Rust-colored sputum\nE Grayish yellow sputum"),
    
    ("All of the following can cause obstructive jaundice, EXCEPT:",
     "A Malaria\nB Cholangiocarcinoma\nC Liver cancer\nD Biliary ascariasis\nE Common bile duct stone"),
    
    ("Which disease may cause barking cough with dyspnea?",
     "A Pleurisy\nB Pneumococcal pneumonia\nC Cavitary tuberculosis\nD Bronchiectasis\nE Laryngeal edema"),
    
    ("Which of the following is characteristic of central cyanosis?",
     "A Cyanosis disappears after local massage\nB Most commonly seen around lips\nC Skin temperature is low and cold\nD Generalized cyanosis with warm skin\nE Cyanosis usually appears at extremities"),
    
    ("Which of the following may cause central vomiting?",
     "A Pyloric obstruction\nB Digitalis intoxication\nC Acute peritonitis\nD Acute myocardial infarction\nE Labyrinthitis")
]
# New batch of questions for translation
batch4 = [
    ("Which of the following causes of headache is extracranial in origin?",
     "A Trigeminal neuralgia\nB Meningitis\nC Uremia\nD Concussion\nE Brain tumor"),
    
    ("All of the following can present with chest pain, EXCEPT:",
     "A Herpes zoster\nB Lung cancer\nC Pneumothorax\nD Pericarditis\nE Asthma"),
    
    ("A patient developed facial drooping and drooling the morning after exposure to cold wind. Exam reveals widened palpebral fissure on one side, inability to wrinkle the forehead, shallow nasolabial fold, and mouth corner droop. The most likely diagnosis is:",
     "A Subarachnoid hemorrhage\nB Brain tumor\nC Cerebral infarction\nD Cerebral hemorrhage\nE Peripheral facial nerve palsy"),
    
    ("Which of the following is a possible finding in acute cholecystitis?",
     "A Positive McBurney's point tenderness\nB Positive Murphy's sign\nC Positive fluid wave\nD Positive succussion splash\nE Positive shifting dullness"),
    
    ("What is the main mechanism of murmur in infective endocarditis?",
     "A Accelerated blood flow\nB Valvular stenosis\nC Valvular insufficiency\nD Abnormal communications\nE Intracardiac floating structures"),
    
    ("A symptom observed in cerebellar lesions is:",
     "A Resting tremor\nB Intention tremor\nC Senile tremor\nD Asterixis\nE Carpopedal spasm"),
    
    ("Boot-shaped heart is commonly seen in:",
     "A Aortic valve insufficiency\nB Pulmonary valve insufficiency\nC Mitral stenosis\nD Mitral valve insufficiency\nE Tricuspid stenosis"),
    
    ("A characteristic sign of rheumatic mitral stenosis is:",
     "A Accentuated first heart sound at the apex\nB Mid-to-late diastolic rumbling murmur at the apex\nC Systolic blowing murmur at the apex\nD Loud and split second heart sound at 2nd left intercostal space\nE Opening snap"),
    
    ("Which murmur is best heard with the patient leaning forward?",
     "A Mid-to-late diastolic rumble of mitral stenosis\nB Systolic blowing murmur of mitral insufficiency\nC Systolic ejection murmur of aortic stenosis\nD Diastolic decrescendo murmur of aortic insufficiency\nE Continuous machinery murmur at 2nd left intercostal space"),
    
    ("In mumps, mucosal redness and swelling at the opening of the parotid duct is most likely observed at:",
     "A Buccal mucosa near upper second molar\nB Buccal mucosa near lower second molar\nC Under the tongue\nD Buccal mucosa near upper first molar\nE Buccal mucosa near lower first molar"),
    
    ("Which of the following is observed in myelofibrosis?",
     "A Sickle cells\nB Spherocytes\nC Anisocytosis\nD Teardrop cells\nE Target cells"),
    
    ("A 50-year-old male has had cough with blood-streaked sputum for 2 months without fever. No improvement with antibiotics. Three chest X-rays show right middle lobe inflammation. The most likely diagnosis is:",
     "A Pneumococcal pneumonia\nB Pulmonary tuberculosis\nC Lung abscess\nD Lung cancer\nE Bronchiectasis"),
    
    ("Reduced respiratory movement, tympanic percussion, and absent breath sounds on one side suggest:",
     "A Lung consolidation\nB Emphysema\nC Lung collapse\nD Pneumothorax\nE Pleural thickening"),
    
    ("A systolic thrill palpable at the 3rd or 4th left intercostal space along the sternum suggests:",
     "A Aortic valve insufficiency\nB Ventricular septal defect\nC Mitral stenosis\nD Tricuspid stenosis\nE Pulmonary valve stenosis"),
    
    ("Normal axillary temperature in adults should be:",
     "A 36–37°C\nB 36.2–37°C\nC 36.2–37.2°C\nD 36.4–37.4°C\nE 36.5–37.5°C"),
    
    ("Teardrop-shaped red cells are commonly seen in:",
     "A Megaloblastic anemia\nB Polycythemia vera\nC Iron deficiency anemia\nD Myelofibrosis\nE All of the above"),
    
    ("Jugular vein pulsation can be seen in:",
     "A Mitral insufficiency\nB Aortic insufficiency\nC Tricuspid insufficiency\nD Pulmonary valve insufficiency\nE Hyperthyroidism"),
    
    ("In hypertensive heart disease with left ventricular enlargement, the cardiac silhouette appears:",
     "A Boot-shaped\nB Pear-shaped\nC Flask-shaped\nD Globular\nE Prominent cardiac waist"),
    
    ("All of the following may show peripheral vascular signs, EXCEPT:",
     "A Aortic insufficiency\nB Fever\nC Anemia\nD Hyperthyroidism\nE Aortic stenosis"),
    
    ("What causes hematemesis to appear dark red?",
     "A Prolonged gastric retention and oxidation\nB Venous rather than arterial blood\nC Hemoglobin denatured by gastric acid\nD Hematemesis due to hypoxia\nE Hemoglobin denatured by sulfides")
]
# Batch 5 translation
batch5 = [
    ("What is a characteristic auscultation finding of the second heart sound?",
     "A Lower pitch\nB Louder intensity\nC Longer duration\nD Less crisp than the first heart sound\nE Best heard at the base of the heart"),
    
    ("In pulmonary emphysema, changes in cardiac dullness typically present as:",
     "A Dullness expands to the left\nB Dullness area is reduced\nC Dullness expands to the right\nD Dullness expands bilaterally\nE None of the above"),
    
    ("When the left ventricle enlarges, the apex beat typically shifts:",
     "A To the right\nB To the left\nC Downward and to the right\nD Downward and to the left\nE Backward"),
    
    ("Visible peristaltic waves in the upper abdomen are most commonly seen in:",
     "A Acute gastritis\nB Chronic gastritis\nC Gastric cancer\nD Peptic ulcer\nE Pyloric obstruction"),
    
    ("Constrictive pericarditis typically presents with:",
     "A Pulsus deficit\nB Water hammer pulse\nC Pulsus paradoxus\nD Jugular venous pulsation\nE Pulsus alternans"),
    
    ("Systolic murmur at the apex in patients with anemia or hyperthyroidism is mainly due to:",
     "A Accelerated blood flow\nB Valvular stenosis\nC Valvular regurgitation\nD Abnormal pathways\nE Intracardiac masses"),
    
    ("Spider angiomas are rare in which of the following locations?",
     "A Cheeks\nB Dorsum of the hand\nC Chest\nD Upper arm\nE Lower limbs"),
    
    ("Which of the following statements is incorrect?",
     "A Jugular vein distension can be seen in supine position in healthy individuals\nB Jugular vein distension can be seen in sitting position in healthy individuals\nC Jugular vein distension is seen in right heart failure\nD Superior vena cava obstruction can cause jugular vein distension\nE Jugular vein distension is present in pericardial effusion"),
    
    ("Which of the following is considered a passive posture?",
     "A Opisthotonos\nB Restless shifting posture\nC Paralysis of limbs\nD Orthopnea\nE None of the above"),
    
    ("Which of the following symptoms is commonly seen with intestinal obstruction?",
     "A Acute fever\nB Jaundice\nC Vomiting\nD Diarrhea\nE Hematochezia"),
    
    ("Positive hepatojugular reflux test suggests which condition?",
     "A Left heart failure\nB Right heart failure\nC Liver cirrhosis\nD Pulmonary emphysema\nE Tricuspid insufficiency"),
    
    ("Cheyne–Stokes respiration is NOT seen in which of the following conditions?",
     "A Brainstem damage\nB Increased intracranial pressure\nC Encephalitis\nD Metabolic acidosis\nE Meningitis"),
    
    ("Which of the following conditions may show hyperresonance on percussion?",
     "A Pulmonary emphysema\nB Pneumothorax\nC Pneumonia\nD Pleural effusion\nE Lung consolidation"),
    
    ("Spider angiomas are NOT typically found in which of the following sites?",
     "A Dorsum of the hand\nB Chest\nC Face\nD Abdomen\nE Neck"),
    
    ("Tactile fremitus in massive pleural effusion is usually:",
     "A Increased\nB Decreased or absent\nC Slightly increased\nD Normal\nE Unchanged"),
    
    ("Which of the following physical signs most strongly indicates peritonitis?",
     "A Decreased bowel sounds\nB Shifting dullness on percussion\nC Abdominal tenderness\nD Palpable abdominal mass\nE Rebound tenderness"),
    
    ("A 40-year-old woman presents with frog-like abdomen in supine position and bulging of the lower side of abdomen in lateral decubitus. What should be considered first?",
     "A Gastrointestinal gas\nB Ascites\nC Giant ovarian cyst\nD Obesity\nE Uterine fibroid"),
    
    ("Presence of shifting dullness on abdominal percussion suggests:",
     "A Urinary retention\nB Pyloric obstruction\nC Right heart failure\nD Giant ovarian cyst\nE Acute gastritis"),
    
    ("Which of the following is NOT a normal percussion sound?",
     "A Succussion splash\nB Resonance\nC Tympany\nD Dullness\nE Flatness"),
    
    ("Spider angiomas are diagnostically significant in which of the following conditions?",
     "A Liver cirrhosis\nB Measles\nC Scarlet fever\nD Typhoid fever\nE Drug allergy")
]
# Batch 6 translation
batch6 = [
    ("Which disease should be considered when dull percussion over the lungs is found?",
     "A Pneumonia\nB Pleuritis\nC Pulmonary cavity\nD Emphysema\nE Massive pleural effusion"),
    
    ("Metallic bowel sounds may be heard in which of the following conditions?",
     "A Paralytic ileus\nB Mechanical intestinal obstruction\nC Hypokalemia\nD Acute enteritis\nE Septicemia"),
    
    ("Which of the following is most useful in distinguishing splenomegaly from intra-abdominal mass?",
     "A Consistency\nB Mobility\nC Presence of tenderness\nD Presence of notch\nE Percussion findings"),
    
    ("Pathologic bronchial breath sounds can be heard at which of the following locations?",
     "A Larynx\nB Suprasternal fossa\nC Near C6–C7 on back\nD Near T1–T2 on back\nE Right lower lung"),
    
    ("A patient has cough. On exam: trachea deviated to the left, right chest more distended, and tympany on percussion. What is the most likely diagnosis?",
     "A Right pneumothorax\nB Left lung collapse\nC Right lower lobe pneumonia\nD Emphysema\nE Right pleural effusion"),
    
    ("Square-shaped skull (frontal bossing) may be seen in:",
     "A Cretinism\nB Congenital syphilis\nC Meningitis\nD Hydrocephalus\nE Malnutrition in children"),
    
    ("A patient has had palpitations and shortness of breath for one year, worsened with exertion. Irregular rhythm and variable heart sound intensity are noted. Most likely arrhythmia is:",
     "A Sinus arrhythmia\nB Sinus tachycardia\nC Premature beats\nD Atrial fibrillation\nE Supraventricular tachycardia"),
    
    ("Which valvular disease produces a localized, non-radiating murmur?",
     "A Mitral regurgitation\nB Mitral stenosis\nC Aortic stenosis\nD Pulmonary stenosis\nE Aortic regurgitation"),
    
    ("Which of the following may present with increased breath sounds?",
     "A Myasthenia gravis\nB Anemia\nC Pleuritis\nD Diaphragm paralysis\nE Acute diffuse peritonitis"),
    
    ("Visible strong peristalsis from left subcostal to right in the abdomen is seen in:",
     "A Gastroptosis\nB Gastric dilation\nC Pyloric obstruction\nD Gastric cancer\nE Acute gastritis"),
    
    ("In pulmonary emphysema, percussion typically reveals:",
     "A Resonance\nB Hyperresonance\nC Dullness\nD Tympany\nE Flatness"),
    
    ("What is the typical posture adopted by a patient with angina pectoris?",
     "A Forced sitting\nB Restless rolling\nC Forced squatting\nD Standing still\nE Lying on one side"),
    
    ("A child has a prominent sternum, sunken chest wall, thickened costochondral junctions forming bead-like appearance. The most likely diagnosis is:",
     "A Pulmonary tuberculosis\nB Rickets\nC Emphysema\nD Bronchial asthma\nE Pulmonary fibrosis"),
    
    ("Abdominal pain with vomiting, distention, and cessation of flatus and feces suggests:",
     "A Intestinal obstruction\nB Acute bacillary dysentery\nC Acute cholecystitis\nD Tuberculous peritonitis\nE Acute intra-abdominal bleeding"),
    
    ("What is the typical blood pressure difference between both upper limbs in normal individuals?",
     "A 5–10 mmHg\nB 11–15 mmHg\nC 16–20 mmHg\nD 21–25 mmHg\nE 26–30 mmHg"),
    
    ("A systolic murmur heard at the 2nd left intercostal space near the sternum suggests:",
     "A Aortic stenosis\nB Pulmonary stenosis\nC Mitral stenosis\nD Tricuspid stenosis\nE Atrial septal defect"),
    
    ("Tracheal deviation toward the affected side can be seen in:",
     "A Pleural effusion\nB Pneumothorax\nC Emphysema\nD Lung collapse\nE Lung consolidation"),
    
    ("Splashing sound heard in fasting state suggests:",
     "A Cirrhotic ascites\nB Nephrotic syndrome\nC Tuberculous peritonitis\nD Pyloric obstruction\nE Acute enteritis"),
    
    ("The key point in differentiating pericardial friction rub from pleural friction rub is:",
     "A History of heart disease\nB Rapid breathing\nC Disappears with position change\nD Disappears with breath holding\nE Disappears after coughing"),
    
    ("Pericardial friction rub is best heard at:",
     "A Apex\nB Base of heart\nC 3rd–4th left intercostal space near sternum\nD 3rd–4th right intercostal space near sternum\nE 3rd–4th left anterior axillary line")
]

# Batch 7 translation
batch7 = [
    ("Where are bronchovesicular breath sounds normally heard?",
     "A Left supraclavicular fossa\nB Right supraclavicular fossa\nC Around the sternal angle\nD Suprasternal fossa\nE Inter-scapular area"),

    ("What is the normal ratio of respiration to pulse in healthy individuals?",
     "A 1:1\nB 1:2\nC 1:3\nD 1:4\nE 1:5"),

    ("Which of the following can cause postural scoliosis?",
     "A Rickets\nB Congenital torticollis\nC Pleuritic thickening\nD Unilateral psoas paralysis\nE Poor posture during childhood development"),

    ("Which of the following is commonly seen in aortic regurgitation?",
     "A Pulse deficit\nB Water hammer pulse\nC Pulsus paradoxus\nD Jugular venous pulse\nE Pulsus alternans"),

    ("Which of the following is NOT a characteristic auscultatory finding of atrial fibrillation?",
     "A Completely irregular rhythm\nB Pulse deficit\nC Variable intensity of heart sounds\nD Murmurs frequently heard\nE Variable heart rate"),

    ("Pathological bilateral pupil constriction may be seen in:",
     "A Organophosphate poisoning\nB Glaucoma\nC Optic nerve atrophy\nD Brain tumor\nE Brain herniation"),

    ("Which respiratory pattern is often seen in massive ascites?",
     "A Sighing respiration\nB Deep inspiration\nC Thoracic breathing\nD Abdominal breathing\nE Mixed breathing"),

    ("Intussusception is commonly associated with abdominal pain and which of the following?",
     "A Acute fever\nB Jaundice\nC Vomiting\nD Diarrhea\nE Bloody stools"),

    ("What gait abnormality is seen in peroneal nerve paralysis?",
     "A Scissor gait\nB Ataxic gait\nC Festinating gait\nD Steppage gait\nE Waddling gait"),

    ("Hyperresonance on percussion may be due to:",
     "A Tapping on elastic, air-filled normal lung\nB Tapping on air-filled hollow viscera\nC Tapping on hyperinflated lung with reduced elasticity\nD Tapping on non-air-containing solid organs\nE Tapping on hypoinflated lung due to various causes"),

    ("Pathologic bronchial breath sounds may be heard in which location?",
     "A Subscapular region\nB Larynx\nC Suprasternal fossa\nD Near the 6th cervical vertebra posteriorly\nE None of the above"),

    ("A patient presents with recurrent vomiting of undigested food. Physical exam shows cachexia, upper abdominal distention, and visible gastric peristalsis. The most likely diagnosis is:",
     "A Hepatitis\nB Cirrhosis\nC Gastritis\nD Pyloric obstruction\nE Cholecystitis"),

    ("Where is vesicular breath sound most clearly heard in healthy individuals?",
     "A Larynx\nB Lower scapular region\nC Around the sternal angle\nD Right lung apex\nE Upper scapular region"),

    ("Which sign is associated with pyloric obstruction?",
     "A McBurney's point tenderness\nB Murphy's sign\nC Fluid wave\nD Succussion splash\nE Shifting dullness"),

    ("All of the following may cause clubbing of the fingers except:",
     "A High altitude disease\nB Iron-deficiency anemia\nC Rheumatic fever\nD Onychomycosis\nE Ulnar nerve injury"),

    ("Jugular venous pulsation during ventricular systole may be seen in:",
     "A Hypertension\nB Severe anemia\nC Tricuspid regurgitation\nD Aortic regurgitation\nE Hyperthyroidism"),

    ("If the anterior abdominal wall is at the same horizontal level as the line from the xiphoid process to the pubic symphysis in the supine position, it is called:",
     "A Flat abdomen\nB Full abdomen\nC Protuberant abdomen\nD Low abdomen\nE Sunken abdomen"),

    ("Which of the following is NOT a deep tendon reflex?",
     "A Biceps reflex\nB Triceps reflex\nC Knee jerk\nD Abdominal wall reflex\nE Achilles tendon reflex"),

    ("Which of the following is NOT a pathological reflex seen in pyramidal tract lesions?",
     "A Babinski sign\nB Chaddock sign\nC Gordon sign\nD Lasègue sign\nE Oppenheim sign"),

    ("A patient with palpitations and dyspnea for 3 years has a displaced apical impulse and enlarged cardiac dullness to the left. Auscultation reveals a grade 3/6 coarse systolic blowing murmur and a diastolic rumbling murmur at the apex. What is the most likely diagnosis?",
     "A Isolated mitral stenosis\nB Isolated mitral regurgitation\nC Combined mitral stenosis and regurgitation\nD Aortic stenosis\nE Aortic regurgitation")
]


# Batch 7 continuation translation
batch8 = [
    ("Unequal pupil size (anisocoria) is commonly seen in:",
     "A Organophosphate poisoning\nB Atropine effect\nC Morphine effect\nD Agonal state\nE Brain tumor"),

    ("Which position is best for auscultating mitral valve murmurs?",
     "A Sitting\nB Standing\nC Supine\nD Right lateral decubitus\nE Left lateral decubitus"),

    ("Which condition leads to widened pulse pressure?",
     "A Aortic stenosis\nB Heart failure\nC Hypotension\nD Aortic regurgitation\nE Constrictive pericarditis"),

    ("Which murmur is better heard in the left lateral decubitus position?",
     "A Mid-to-late diastolic rumbling murmur of mitral stenosis\nB Systolic blowing murmur of mitral regurgitation\nC Systolic ejection murmur of aortic stenosis\nD Diastolic decrescendo murmur of aortic regurgitation\nE Machinery-like murmur at the 2nd left intercostal space"),

    ("Pupil change in atropine poisoning is:",
     "A Mydriasis\nB Miosis\nC White pupils\nD Unequal pupils\nE Irregular-shaped pupils"),

    ("Which of the following can be seen in megaloblastic anemia?",
     "A Sickle cells\nB Spherocytes\nC Anisocytosis\nD Teardrop cells\nE Target cells"),

    ("Which of the following is NOT a deep tendon reflex test?",
     "A Biceps reflex\nB Patellar reflex\nC Cremasteric reflex\nD Achilles reflex\nE Radial periosteal reflex"),

    ("Which of the following can cause bilateral mydriasis?",
     "A Atropine\nB Chlorpromazine\nC Organophosphate poisoning\nD Mushroom poisoning\nE Pilocarpine poisoning"),

    ("Systolic thrill at the 3rd–4th left intercostal space suggests:",
     "A Aortic regurgitation\nB Ventricular septal defect\nC Mitral stenosis\nD Tricuspid stenosis\nE Pulmonary stenosis"),

    ("Which of the following is characteristic of central paralysis?",
     "A Decreased muscle tone\nB Decreased tendon reflexes\nC Loss of superficial reflexes\nD Absence of pathological reflexes\nE Increased muscle tone"),

    ("Carotid pulse is commonly seen in:",
     "A Mitral regurgitation\nB Aortic regurgitation\nC Tricuspid regurgitation\nD Pulmonary regurgitation\nE Mitral stenosis"),

    ("Grade III tonsillar hypertrophy is defined as:",
     "A Enlargement does not exceed palatoglossal arch\nB Enlargement does not exceed the uvula\nC Enlargement does not exceed midline of posterior pharyngeal wall\nD Enlargement exceeds palatoglossal arch but not to midline\nE Enlargement reaches or exceeds midline of posterior pharyngeal wall"),

    ("Which finding is most useful in differentiating splenomegaly from abdominal mass?",
     "A Consistency\nB Mobility\nC Presence of tenderness\nD Presence of notch\nE Percussion findings"),

    ("What is the change in cardiac dullness in patients with emphysema?",
     "A Enlarged to lower left\nB Enlarged to the right\nC Enlarged bilaterally\nD Reduced\nE Unchanged"),

    ("Which is a typical manifestation of rheumatoid arthritis?",
     "A Spindle-shaped deformity of fingers\nB Clubbing\nC Koilonychia\nD Patellar floating\nE Acromegaly"),

    ("ST segment depression (≥0.1 mV) on ECG suggests:",
     "A Atrial fibrillation\nB Variant angina\nC Premature beat\nD Angina pectoris\nE Ventricular tachycardia"),

    ("Which of the following may show subdiaphragmatic free air on upright chest X-ray?",
     "A Acute gastric perforation\nB Intestinal obstruction\nC Intussusception\nD Liver rupture\nE Colon tumor"),

    ("Which test is most useful in diagnosing typhoid fever?",
     "A Remittent fever\nB Positive blood culture\nC Splenomegaly\nD Hepatomegaly\nE Relative bradycardia"),

    ("Which condition is most likely to cause metabolic alkalosis?",
     "A Chronic renal failure\nB Shock\nC Intestinal fistula\nD Pyloric obstruction\nE Acute renal failure"),

    ("Which statement about clinical use of chest X-ray is incorrect?",
     "A Diagnose respiratory diseases\nB Assess respiratory function\nC Cancer screening\nD Tuberculosis screening\nE Occupational disease prevention")
]

# Batch 9 translation
batch9 = [
    ("Which wave reflects the electrical excitation of both atria?",
     "A P wave\nB P-R segment\nC QRS complex\nD ST segment\nE T wave"),

    ("Rv5 + Sv1 > 4.0 mV suggests which diagnosis?",
     "A Left ventricular high voltage\nB Left ventricular strain\nC Right ventricular hypertrophy\nD Biventricular hypertrophy\nE Left ventricular hypertrophy with strain"),

    ("Rv5 > 2.5 mV, ST depression in V5 > 0.05 mV, inverted T wave in V5, electrical axis −22°, suggests:",
     "A Left ventricular high voltage\nB Left ventricular strain\nC Right ventricular hypertrophy\nD Biventricular hypertrophy\nE Left ventricular hypertrophy with strain"),

    ("Which is the simplest method to examine solid abdominal organs?",
     "A X-ray\nB CT scan\nC Radionuclide scanning\nD B-mode ultrasound\nE Fiberoptic endoscopy"),

    ("Right atrial hypertrophy on ECG is characterized by:",
     "A Peaked P wave\nB Flattened P wave\nC Notched P wave\nD Widened P wave\nE P wave with notch"),

    ("Which interval represents total time of ventricular depolarization and repolarization?",
     "A P wave\nB QRS complex\nC ST segment\nD T wave\nE Q-T interval"),

    ("Lead V6 is most useful to locate infarction in the:",
     "A Anteroseptal wall\nB Anterior wall\nC Lateral wall\nD Inferior wall (diaphragmatic)\nE Posterior wall"),

    ("Typical X-ray feature of lung atelectasis is:",
     "A Cloud-like shadow with unclear boundaries\nB High-density scattered flower-like shadows\nC Sharply outlined coarse linear opacities\nD High-density patchy infiltrates\nE Triangular homogeneous density shadow"),

    ("All of the following can be distinguished with chest X-ray EXCEPT:",
     "A Hemorrhagic vs purulent pleural effusion\nB Lobar vs bronchopneumonia\nC Pneumothorax vs bulla\nD Atelectasis vs consolidation\nE Lung abscess vs tumor"),

    ("Best test for evaluating severity of mitral stenosis is:",
     "A Auscultation\nB Chest X-ray\nC ECG\nD Chest CT\nE 2D echocardiography"),

    ("ECG change indicating myocardial injury is:",
     "A ST depression\nB Marked ST elevation with convex curve\nC Peaked T wave\nD Inverted T wave\nE Abnormally deep and wide Q wave"),

    ("ECG change indicating myocardial necrosis is:",
     "A ST depression\nB Marked ST elevation with convex curve\nC Peaked T wave\nD Inverted T wave\nE Abnormally deep and wide Q wave"),

    ("Preferred test for suspected spontaneous pneumothorax is:",
     "A B-mode ultrasound\nB Chest CT\nC Chest X-ray\nD MRI\nE Fiberoptic bronchoscopy"),

    ("Creatinine clearance value in decompensated renal failure is:",
     "A 120–80 ml/min\nB <10 ml/min\nC 19–10 ml/min\nD 50–20 ml/min\nE 80–51 ml/min"),

    ("Urine finding suggestive of acute pyelonephritis is:",
     "A Hyaline casts\nB Granular casts\nC WBC casts\nD Fatty casts\nE Waxy casts"),

    ("Which of the following statements about alkaline phosphatase (ALP) is incorrect?",
     "A ALP increases significantly in obstructive jaundice\nB Mild ALP increase in hepatocellular jaundice\nC Significant ALP increase in intrahepatic bile duct obstruction\nD ALP does not increase in bone disease\nE Significant ALP increase in intrahepatic cholestasis"),

    ("Elevated total WBC count can be seen in:",
     "A Aplastic anemia\nB Acute hemorrhage\nC Chloramphenicol use\nD Hypersplenism\nE Typhoid infection"),

    ("Which sputum finding is typical in pulmonary congestion due to heart failure?",
     "A Leukocytes\nB Charcot-Leyden crystals\nC Epithelial cells\nD Pigment-laden macrophages\nE Curschmann spirals"),

    ("The most common cast type in pyelonephritis is:",
     "A RBC casts\nB WBC casts\nC Epithelial cell casts\nD Hyaline casts\nE Waxy casts"),

    ("Which stool characteristic is seen in upper GI bleeding?",
     "A Watery stools\nB Rice water stools\nC Fresh blood\nD Melena\nE Clay-colored stools")
]
batch10 = [
    ("What cell type is found in sputum during pulmonary congestion from heart failure?",
     "A Leukocytes\nB Charcot-Leyden crystals\nC Epithelial cells\nD Hemosiderin-laden macrophages\nE Curschmann’s spirals"),

    ("What is the normal range of total serum protein?",
     "A 80–100 g/L\nB 45–55 g/L\nC 60–80 g/L\nD 20–30 g/L\nE 40–50 g/L"),

    ("Which urinary finding suggests severe tubular damage and poor prognosis?",
     "A Hyaline casts\nB Granular casts\nC Leukocyte casts\nD Fatty casts\nE Waxy casts"),

    ("Which statement about endogenous creatinine clearance rate is correct?",
     "A Increases in severe renal dysfunction\nB Values >80 ml/min suggest poor prognosis\nC Lower clearance indicates more severe renal damage\nD Higher clearance indicates more severe renal damage\nE Not related to kidney function impairment"),

    ("Which statement about hyperthyroidism is correct?",
     "A Both T3 and T4 must be elevated for diagnosis\nB Both T3 and T4 must be decreased for diagnosis\nC Elevated T3 alone can confirm diagnosis\nD T3 increases while T4 decreases\nE None of the above"),

    ("Moderate increases in total, conjugated, and unconjugated bilirubin suggest:",
     "A Favism\nB Cholelithiasis\nC Thalassemia\nD Acute icteric hepatitis\nE Pancreatic head carcinoma"),

    ("What is the normal serum sodium level in adults?",
     "A 110–120 mmol/L\nB 121–130 mmol/L\nC 135–145 mmol/L\nD 150–155 mmol/L\nE 156–160 mmol/L"),

    ("Which urinary cast may be occasionally seen in normal individuals?",
     "A Red cell casts\nB White cell casts\nC Epithelial cell casts\nD Hyaline casts\nE Waxy casts"),

    ("Which serum enzyme is most valuable in diagnosing acute pancreatitis?",
     "A AST\nB Amylase\nC Alkaline phosphatase\nD ALT\nE LDH"),

    ("How many WBCs per high-power field in urine microscopy are considered abnormal?",
     "A >3\nB >1\nC >5\nD >8\nE >10"),

    ("Which condition may cause pathologic neutrophilia?",
     "A Measles\nB Acute hemolysis\nC Malignant histiocytosis\nD Systemic lupus erythematosus\nE Hypersplenism"),

    ("Which condition usually does NOT present with proteinuria?",
     "A Febrile pyogenic tonsillitis\nB Grade 3 hypertension\nC Preeclampsia\nD Ischemic heart disease (during angina attack)\nE Chronic right heart failure"),

    ("What is the normal reference range for AST (aspartate transaminase)?",
     "A <10 U/L\nB <20 U/L\nC <30 U/L\nD <40 U/L\nE <50 U/L"),

    ("Which of the following does NOT typically cause pathological hyperglycemia?",
     "A Hyperthyroidism\nB Pheochromocytoma\nC Diabetes mellitus\nD Cushing's syndrome\nE Insulinoma"),

    ("A 55-year-old man experiences repeated short episodes of chest pain after exertion or stress. Which serum test is most informative for diagnosis?",
     "A Potassium\nB Sodium\nC Chloride\nD Calcium\nE Cholesterol and triglycerides"),

    ("Which is considered pathological proteinuria?",
     "A After vigorous exercise\nB After severe cold exposure\nC Orthostatic proteinuria\nD Preeclampsia\nE None of the above"),

    ("Leukocytosis may be seen in:",
     "A Typhoid fever\nB Aplastic anemia\nC Acute blood loss\nD Chloramphenicol use\nE Hypersplenism"),

    ("Which condition does NOT cause positive urinary ketones?",
     "A Starvation\nB Binge eating\nC Hyperemesis gravidarum\nD Diabetic ketoacidosis\nE Anorexia nervosa"),

    ("Auer rods in bone marrow cells are typically seen in:",
     "A Acute lymphoblastic leukemia\nB Acute myeloid leukemia\nC Chronic myeloid leukemia\nD Hemolytic anemia\nE Systemic lupus erythematosus"),

    ("Which test is most valuable in diagnosing myocardial infarction?",
     "A Amylase\nB Serum transaminases\nC Gamma-glutamyl transferase (GGT)\nD Serum alkaline phosphatase\nE Creatine kinase (CK)")
]


batch10_df = pd.DataFrame(batch10, columns=["Question", "Options"])

batch9_df = pd.DataFrame(batch9, columns=["Question", "Options"])

batch8_df = pd.DataFrame(batch8, columns=["Question", "Options"])

# Create and display dataframe
batch7_df = pd.DataFrame(batch7, columns=["Question", "Options"])


# Create dataframe and show
batch6_df = pd.DataFrame(batch6, columns=["Question", "Options"])

# Create dataframe and show
batch5_df = pd.DataFrame(batch5, columns=["Question", "Options"])

# Create dataframe and show it
batch4_df = pd.DataFrame(batch4, columns=["Question", "Options"])

# Create dataframe and show it
batch3_df = pd.DataFrame(batch3, columns=["Question", "Options"])

# Append to existing DataFrame
batch2_df = pd.DataFrame(batch2, columns=["Question", "Options"])

# Create DataFrame
batch1_df = pd.DataFrame(batch1, columns=["Question", "Options"])

dataframes = []

# Each batch is a tuple list (Question, Options) already defined
batch_names = ['data', 'new_data', 'batch3', 'batch4', 'batch5', 'batch6']

# Simulated as if these are already available as lists of tuples
dataframes.append(pd.DataFrame(batch1, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch2, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch3, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch4, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch5, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch6, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch7, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch8, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch9, columns=["Question", "Options"]))
dataframes.append(pd.DataFrame(batch10, columns=["Question", "Options"]))

# Combine all batches into one DataFrame
combined_df = pd.concat(dataframes, ignore_index=True)

# Export to CSV
output_path = "q.csv"
combined_df.to_csv(output_path, index=False)

# %%
eng = pd.read_csv("q.csv")
print(f"GPTsum: {len(df)}")
print(f"truthSum: {len(true_answers)}")
# Out:
# GPTsum: 200
# truthSum: 200

# %%
chunk_size = 20
chunks = [combined_df.iloc[i:i + chunk_size] for i in range(0, len(df_sampled), chunk_size)]

output_paths = []
for i, chunk in enumerate(chunks):
    path = f"english_batch{i+1}.csv"
    chunk.to_csv(path, index=False)
    output_paths.append(path)

output_paths
# Out:
# ['english_batch1.csv',
#  'english_batch2.csv',
#  'english_batch3.csv',
#  'english_batch4.csv',
#  'english_batch5.csv',
#  'english_batch6.csv',
#  'english_batch7.csv',
#  'english_batch8.csv',
#  'english_batch9.csv',
#  'english_batch10.csv']

# %%
eng_ans=[
    ['D', 'D', 'B', 'A', 'A', 'D', 'E', 'E', 'A', 'A', 'C', 'C', 'C', 'A', 'C', 'D', 'C', 'C', 'C', 'B']
    ,['B', 'A', 'E', 'B', 'D', 'E', 'B', 'A', 'B', 'A',
       'C', 'B', 'C', 'D', 'E', 'D', 'D', 'A', 'B', 'A'],
    ['B', 'A', 'A', 'A', 'B', 'B', 'A', 'A', 'C', 'B',
       'A', 'E', 'B', 'A', 'C', 'D', 'A', 'E', 'B', 'B']
    ,['A', 'E', 'E', 'B', 'C', 'B', 'E', 'B', 'D', 'A',
       'D', 'D', 'D', 'B', 'C', 'C', 'D', 'C', 'B', 'E', 'A'],
       ['E', 'B', 'D', 'E', 'D', 'A', 'E', 'B', 'C', 'C',
       'B', 'D', 'A', 'A', 'B', 'E', 'B', 'C', 'A', 'A'],
       ['E', 'D', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C',
       'E', 'D', 'B', 'D', 'D', 'C', 'A', 'D', 'D', 'C'],
       ['A', 'B', 'D', 'E', 'A', 'B', 'D', 'B', 'B', 'C','B', 'D', 'B', 'A', 'A', 'B', 'D', 'D', 'D', 'C'],
['E', 'D', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C', 'E', 'D', 'B', 'D', 'D', 'C', 'A', 'D', 'D', 'C'],
['E', 'E', 'D', 'A', 'A', 'C', 'C', 'A', 'B', 'E',
       'B', 'E', 'D', 'D', 'A', 'D', 'A', 'B', 'D', 'B'],
['D', 'C', 'E', 'C', 'C', 'D', 'C', 'D', 'B', 'C',
       'C', 'D', 'D', 'E', 'E', 'D', 'C', 'B', 'B', 'E']



]

# %%
flat_eng_gpt = [ans for group in eng_gpt for ans in group]

print(flat_eng_gpt)
# Out:
# ['D', 'D', 'B', 'A', 'A', 'D', 'E', 'E', 'A', 'A', 'C', 'C', 'C', 'A', 'C', 'D', 'C', 'C', 'C', 'B', 'B', 'A', 'E', 'B', 'D', 'E', 'B', 'A', 'B', 'A', 'C', 'B', 'C', 'D', 'E', 'D', 'D', 'A', 'B', 'A', 'B', 'A', 'A', 'A', 'B', 'B', 'A', 'A', 'C', 'B', 'A', 'E', 'B', 'A', 'C', 'D', 'A', 'E', 'B', 'B', 'A', 'E', 'E', 'B', 'C', 'B', 'E', 'B', 'D', 'A', 'D', 'D', 'D', 'B', 'C', 'C', 'D', 'C', 'B', 'E', 'A', 'E', 'B', 'D', 'E', 'D', 'A', 'E', 'B', 'C', 'C', 'B', 'D', 'A', 'A', 'B', 'E', 'B', 'C', 'A', 'A', 'E', 'D', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C', 'E', 'D', 'B', 'D', 'D', 'C', 'A', 'D', 'D', 'C', 'A', 'B', 'D', 'E', 'A', 'B', 'D', 'B', 'B', 'C', 'B', 'D', 'B', 'A', 'A', 'B', 'D', 'D', 'D', 'C', 'E', 'D', 'E', 'B', 'D', 'A', 'C', 'E', 'D', 'C', 'E', 'D', 'B', 'D', 'D', 'C', 'A', 'D', 'D', 'C', 'E', 'E', 'D', 'A', 'A', 'C', 'C', 'A', 'B', 'E', 'B', 'E', 'D', 'D', 'A', 'D', 'A', 'B', 'D', 'B', 'D', 'C', 'E', 'C', 'C', 'D', 'C', 'D', 'B', 'C', 'C', 'D', 'D', 'E', 'E', 'D', 'C', 'B', 'B
# ...

# %%
correct = sum([g == t for g, t in zip(flat_eng_gpt, true_answers)])

wrong_indices = [i for i, (g, t) in enumerate(zip(flat_eng_gpt, true_answers)) if g != t]

print(f"ALLnum: {len(true_answers)}")
print(f"Correct: {correct}")
print(f"Accuracy: {correct / len(true_answers) * 100:.2f}%")
print(f"Wrong indices: {wrong_indices}")
# Out:
# ALLnum: 200
# Correct: 94
# Accuracy: 47.00%
# Wrong indices: [12, 39, 51, 54, 58, 64, 66, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 86, 87, 88, 90, 91, 92, 93, 94, 95, 96, 97, 98, 100, 101, 104, 105, 106, 107, 108, 109, 110, 111, 112, 113, 114, 115, 116, 117, 119, 121, 122, 123, 124, 126, 127, 128, 129, 130, 131, 132, 133, 134, 135, 136, 139, 140, 143, 144, 145, 146, 147, 148, 149, 150, 153, 154, 156, 157, 159, 160, 161, 165, 167, 169, 170, 171, 172, 174, 175, 176, 177, 180, 181, 182, 183, 185, 186, 187, 188, 189, 190, 191, 193, 195, 196, 197, 199]
